# %%
import pandas as pd
import datetime
import numpy as np
import os

# %%
filepath12 = os.path.join("../Resources" ,"JC-201912-citibike-tripdata.csv")
filepath1 = os.path.join("../Resources" ,"JC-201901-citibike-tripdata.csv")
filepath2 = os.path.join("../Resources" ,"JC-201902-citibike-tripdata.csv")
filepath3 = os.path.join("../Resources" ,"JC-201903-citibike-tripdata.csv")
filepath4 = os.path.join("../Resources" ,"JC-201904-citibike-tripdata.csv")
filepath5 = os.path.join("../Resources" ,"JC-201905-citibike-tripdata.csv")
filepath6 = os.path.join("../Resources" ,"JC-201906-citibike-tripdata.csv")
filepath7 = os.path.join("../Resources" ,"JC-201907-citibike-tripdata.csv")
filepath8 = os.path.join("../Resources" ,"JC-201908-citibike-tripdata.csv")
filepath9 = os.path.join("../Resources" ,"JC-201909-citibike-tripdata.csv")
filepath10 = os.path.join("../Resources" ,"JC-201910-citibike-tripdata.csv")
filepath11 = os.path.join("../Resources" ,"JC-201911-citibike-tripdata.csv")

Citibike_Jan = pd.read_csv(filepath1)
Citibike_Feb = pd.read_csv(filepath2)
Citibike_Mar = pd.read_csv(filepath3)

# %%
Citibike_Jan.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
Citibike1 = pd.concat([Citibike_Jan,Citibike_Feb,Citibike_Mar])

# %%
Citibike_Apr = pd.read_csv(filepath4)
Citibike_May = pd.read_csv(filepath5)
Citibike_Jun = pd.read_csv(filepath6)

# %%
Citibike2 = pd.concat([Citibike_Apr,Citibike_May,Citibike_Jun])

# %%
Citibike_Jul = pd.read_csv(filepath7)
Citibike_Aug = pd.read_csv(filepath8)
Citibike_Sep = pd.read_csv(filepath9)

# %%
Citibike3 = pd.concat([Citibike_Jul,Citibike_Aug,Citibike_Sep])

# %%
Citibike_Oct = pd.read_csv(filepath10)
Citibike_Nov = pd.read_csv(filepath11)
Citibike_Dec = pd.read_csv(filepath12)

# %%
Citibike4 = pd.concat([Citibike_Oct,Citibike_Nov,Citibike_Dec])

# %%
Citibike1.to_csv("Citibike1.csv")
Citibike2.to_csv("Citibike2.csv")
Citibike3.to_csv("Citibike3.csv")
Citibike4.to_csv("Citibike4.csv")
Citibike4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           892  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1           374  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2           170  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3           946  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4           517  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3211         Newark Ave               40.721525
# 2              3194    McGinley Square               40.725340
# 3              3272       Jersey & 3rd               40.723332
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id            end station name  \
# 0               -74.038914            3280                 Astor Place
# ...

# %%
Citibike_2019 = pd.concat([Citibike1,Citibike2,Citibike3,Citibike4])

# %%
Citibike_2019.to_csv("Citibike_2019.csv")
